# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten
import matplotlib.pyplot as plt
import itertools
import datetime
from keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
data_directory = 'training_data/'
image_file = 'eFEDS_01to18-3dImgs-7946clus-300pix-50pix-ext_det_thr.pickle'
catalog_file = 'eFEDS_mock_clusters_catalog_01to18-ext_det_thr.f'

# %%
def get_data(image_p, catalog_f):
    '''
    Given the image and catalogue path, this function returns the
    images and labels needed to start directly with model training.
    train_labels: Can be used to filter a particular mass range
    Returns:
    images: [index, energy-band-image]
    labels_z: [log10(mass), redshift, index]
    '''
    is_efedssim=True
    is_efedsobs=False
    images = pd.read_pickle(image_p)
    key_mass = 'm500_wl_final' if is_efedsobs else 'M500c' if is_efedssim else 'HALO_M500c'
    key_redshift = 'z_final' if is_efedsobs else 'z' if is_efedssim else 'redshift_R'
    catalog_df = pd.read_feather(catalog_f)
    labels = np.log10(catalog_df[key_mass])
    redshifts = catalog_df[key_redshift].values
    indices = catalog_df.index.values
    labels_z = np.transpose([labels, redshifts, indices])
    return images, labels_z

# %%
images, labels_z = get_data(image_p=data_directory+image_file, catalog_f=data_directory+catalog_file)
masses = labels_z[:,0]
redshifts = labels_z[:,1]

# %%
# Split the data into training, validation, and test sets
# The random state ensures that the split is reproducible
X_train, X_test, y_train, y_test = train_test_split(images['gsm_3dImgs'], masses, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

X_train = np.array(X_train)
Y_train = np.array(y_train)
X_val = np.array(X_val)
Y_val = np.array(y_val)
X_test = np.array(X_test)
Y_test = np.array(y_test)


# Print the shapes of the resulting sets
print(f"Train set: {X_train.shape}, {y_train.shape}")
print(f"Validation set: {X_val.shape}, {y_val.shape}")
print(f"Test set: {X_test.shape}, {y_test.shape}")
# Out:
# Train set: (5084, 50, 50, 10), (5084,)
# Validation set: (1272, 50, 50, 10), (1272,)
# Test set: (1590, 50, 50, 10), (1590,)

# %%
def regression_model(filters, kernel_size, conv_pool_layers, dense_layers):
    '''
    This function builds a regression CNN for the given hyperparameters.
    '''

    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Conv2D(filters, (kernel_size, kernel_size), activation='relu', input_shape=(50, 50, 10)))
    model.add(tf.keras.layers.MaxPooling2D((kernel_size, kernel_size)))

    for i in range(conv_pool_layers-1):
        model.add(tf.keras.layers.Conv2D(int(filters + (i+1)*10), kernel_size, activation='relu'))
        model.add(tf.keras.layers.MaxPooling2D((2, 2)))

    model.add(Flatten())

    # Add Dense layers for regression
    for i in range(dense_layers):
        model.add(Dense(int(64 - i*20), activation='relu'))
    model.add(Dense(1)) # No activation function is used for the output layer because it's a regression problem

    # Compile the model
    model.compile(optimizer='adam',
                loss='mean_squared_error')

    # Print the summary of the model
    model.summary()

    return model

# %%
model = regression_model(filters = 10, kernel_size=3, conv_pool_layers = 1, dense_layers = 1) #create the model
early_stopping = EarlyStopping(monitor='val_loss', patience=30, verbose=1, mode='min', restore_best_weights=True)

history = model.fit(np.array(X_train), np.array(Y_train), validation_data = (np.array(X_val), np.array(
    Y_val)), epochs=300, callbacks=[early_stopping], batch_size=64, verbose = 1)

val_loss = history.history['val_loss'] #get the validation loss
loss = history.history['loss'] #get the training loss
predictions = model.predict(np.array(X_test)) #get the predictions

# plot the predictions on a scatter plot
plt.title('Predicted vs Actual')
plt.plot(Y_test, Y_test, 'r--')
plt.xlim(13,15)
plt.ylim(13,15)
plt.scatter(Y_test[:], predictions[:], alpha = 0.1)
plt.xlabel('actual mass of the cluster ($log_{10}$)')
plt.ylabel('predicted mass of the cluster')
plt.legend()
plt.savefig('naive_predictions.png', dpi = 300)

#save the model
model.save('naive_model.h5')
# Out:
# Metal device set to: Apple M1
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 10)        910
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 10)       0
#  )
#
#  flatten (Flatten)           (None, 2560)              0
#
#  dense (Dense)               (None, 64)                163904
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 164,879
# Trainable params: 164,879
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/300
# 2023-05-26 16:47:58.407280: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 80/80 [==============================] - 2s 21ms/step - loss: 152.9593 - val_loss: 34.3146
# Epoch 2/300
# 80/80 [==============================] - 1s 16ms/step - loss: 9.6184 - val_loss: 4.4460
# Epoch 3/300
# 80/80 [==============================] - 1s 15ms/step - loss: 1.9190 - val_loss: 3.3652
# Epoch 4/300
# 80/80 [==============================] - 1s 15ms/step - loss: 1.1331 - val_loss: 2.5579
# Epoch 5/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.7350 - val_loss: 1.9460
# Epoch 6/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.5399 - val_loss: 1.5762
# Epoch 7/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.4202 - val_loss: 1.1396
# Epoch 8/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.3379 - val_loss: 0.8848
# Epoch 9/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2979 - val_loss: 0.6230
# Epoch 10/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2552 - val_loss: 0.4943
# Epoch 11/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2443 - val_loss: 0.4708
# Epoch 12/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.4967 - val_loss: 0.4194
# Epoch 13/300
# 80/80 [==============================] - 1s 15ms/step - loss: 1.4195 - val_loss: 0.3466
# Epoch 14/300
# 80/80 [==============================] - 1s 15ms/step - loss: 1.4277 - val_loss: 0.4219
# Epoch 15/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.6368 - val_loss: 0.3239
# Epoch 16/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1893 - val_loss: 0.2997
# Epoch 17/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1807 - val_loss: 0.2896
# Epoch 18/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2054 - val_loss: 0.2639
# Epoch 19/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2024 - val_loss: 0.2872
# Epoch 20/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1930 - val_loss: 0.2490
# Epoch 21/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2084 - val_loss: 0.2847
# Epoch 22/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2149 - val_loss: 0.2438
# Epoch 23/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1829 - val_loss: 0.2752
# Epoch 24/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1530 - val_loss: 0.2229
# Epoch 25/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1537 - val_loss: 0.2292
# Epoch 26/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1628 - val_loss: 0.2438
# Epoch 27/300
# 80/80 [==============================] - 2s 19ms/step - loss: 0.2092 - val_loss: 0.2318
# Epoch 28/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2269 - val_loss: 0.2290
# Epoch 29/300
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2191 - val_loss: 0.3103
# Epoch 30/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1996 - val_loss: 0.2130
# Epoch 31/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1843 - val_loss: 0.2252
# Epoch 32/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1698 - val_loss: 0.2218
# Epoch 33/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1997 - val_loss: 0.2548
# Epoch 34/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2339 - val_loss: 0.2337
# Epoch 35/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2145 - val_loss: 0.2147
# Epoch 36/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1993 - val_loss: 0.2176
# Epoch 37/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1938 - val_loss: 0.2057
# Epoch 38/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1894 - val_loss: 0.1936
# Epoch 39/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2043 - val_loss: 0.2087
# Epoch 40/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2250 - val_loss: 0.2470
# Epoch 41/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2570 - val_loss: 0.2136
# Epoch 42/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2438 - val_loss: 0.2051
# Epoch 43/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2305 - val_loss: 0.2238
# Epoch 44/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.4497 - val_loss: 0.2213
# Epoch 45/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.5658 - val_loss: 0.2407
# Epoch 46/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.3058 - val_loss: 0.1974
# Epoch 47/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1393 - val_loss: 0.1879
# Epoch 48/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1077 - val_loss: 0.1808
# Epoch 49/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1003 - val_loss: 0.2394
# Epoch 50/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1157 - val_loss: 0.2463
# Epoch 51/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1018 - val_loss: 0.1849
# Epoch 52/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0959 - val_loss: 0.1772
# Epoch 53/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0967 - val_loss: 0.1718
# Epoch 54/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1143 - val_loss: 0.1959
# Epoch 55/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1110 - val_loss: 0.1730
# Epoch 56/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1186 - val_loss: 0.1846
# Epoch 57/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1191 - val_loss: 0.1717
# Epoch 58/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1099 - val_loss: 0.1903
# Epoch 59/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1516 - val_loss: 0.1755
# Epoch 60/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1077 - val_loss: 0.1723
# Epoch 61/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1127 - val_loss: 0.1798
# Epoch 62/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1189 - val_loss: 0.1760
# Epoch 63/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1115 - val_loss: 0.1702
# Epoch 64/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1023 - val_loss: 0.1693
# Epoch 65/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1130 - val_loss: 0.1875
# Epoch 66/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1298 - val_loss: 0.1671
# Epoch 67/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1783 - val_loss: 0.2160
# Epoch 68/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2512 - val_loss: 0.1883
# Epoch 69/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.3518 - val_loss: 0.3092
# Epoch 70/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2021 - val_loss: 0.1765
# Epoch 71/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1173 - val_loss: 0.1757
# Epoch 72/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1042 - val_loss: 0.1626
# Epoch 73/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0939 - val_loss: 0.1696
# Epoch 74/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0867 - val_loss: 0.1570
# Epoch 75/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0814 - val_loss: 0.2034
# Epoch 76/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0831 - val_loss: 0.1575
# Epoch 77/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0793 - val_loss: 0.1575
# Epoch 78/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0877 - val_loss: 0.1559
# Epoch 79/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0798 - val_loss: 0.1650
# Epoch 80/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0804 - val_loss: 0.1738
# Epoch 81/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0749 - val_loss: 0.1693
# Epoch 82/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0767 - val_loss: 0.2150
# Epoch 83/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0793 - val_loss: 0.1682
# Epoch 84/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0888 - val_loss: 0.1590
# Epoch 85/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0816 - val_loss: 0.1914
# Epoch 86/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1125 - val_loss: 0.1602
# Epoch 87/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1036 - val_loss: 0.1630
# Epoch 88/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1214 - val_loss: 0.2590
# Epoch 89/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1065 - val_loss: 0.1532
# Epoch 90/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0985 - val_loss: 0.2176
# Epoch 91/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1025 - val_loss: 0.1604
# Epoch 92/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1181 - val_loss: 0.1605
# Epoch 93/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1117 - val_loss: 0.1605
# Epoch 94/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0971 - val_loss: 0.1633
# Epoch 95/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0987 - val_loss: 0.1640
# Epoch 96/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0861 - val_loss: 0.1732
# Epoch 97/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0944 - val_loss: 0.1667
# Epoch 98/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0771 - val_loss: 0.1814
# Epoch 99/300
# 80/80 [==============================] - 2s 20ms/step - loss: 0.0812 - val_loss: 0.1589
# Epoch 100/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0826 - val_loss: 0.1529
# Epoch 101/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0961 - val_loss: 0.1522
# Epoch 102/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0898 - val_loss: 0.1608
# Epoch 103/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0884 - val_loss: 0.1582
# Epoch 104/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0855 - val_loss: 0.1584
# Epoch 105/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0901 - val_loss: 0.1522
# Epoch 106/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0869 - val_loss: 0.1698
# Epoch 107/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0946 - val_loss: 0.1760
# Epoch 108/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0976 - val_loss: 0.1561
# Epoch 109/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1002 - val_loss: 0.1491
# Epoch 110/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0954 - val_loss: 0.2059
# Epoch 111/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0893 - val_loss: 0.1756
# Epoch 112/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0832 - val_loss: 0.1617
# Epoch 113/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0723 - val_loss: 0.1601
# Epoch 114/300
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0781 - val_loss: 0.1683
# Epoch 115/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0756 - val_loss: 0.2496
# Epoch 116/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0708 - val_loss: 0.1501
# Epoch 117/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0838 - val_loss: 0.2145
# Epoch 118/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0719 - val_loss: 0.1627
# Epoch 119/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0680 - val_loss: 0.1541
# Epoch 120/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0934 - val_loss: 0.1611
# Epoch 121/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.4996 - val_loss: 0.1738
# Epoch 122/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2266 - val_loss: 0.1473
# Epoch 123/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1304 - val_loss: 0.1355
# Epoch 124/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1212 - val_loss: 0.1746
# Epoch 125/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1150 - val_loss: 0.1308
# Epoch 126/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1053 - val_loss: 0.1289
# Epoch 127/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1103 - val_loss: 0.1812
# Epoch 128/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1046 - val_loss: 0.1483
# Epoch 129/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0955 - val_loss: 0.1295
# Epoch 130/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0935 - val_loss: 0.1300
# Epoch 131/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0975 - val_loss: 0.1252
# Epoch 132/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0931 - val_loss: 0.1275
# Epoch 133/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1038 - val_loss: 0.1240
# Epoch 134/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0900 - val_loss: 0.1937
# Epoch 135/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0871 - val_loss: 0.1303
# Epoch 136/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0884 - val_loss: 0.1235
# Epoch 137/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0836 - val_loss: 0.1244
# Epoch 138/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0849 - val_loss: 0.1348
# Epoch 139/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0810 - val_loss: 0.1281
# Epoch 140/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0952 - val_loss: 0.1248
# Epoch 141/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0906 - val_loss: 0.1588
# Epoch 142/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1031 - val_loss: 0.1354
# Epoch 143/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0935 - val_loss: 0.1337
# Epoch 144/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0880 - val_loss: 0.1274
# Epoch 145/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0949 - val_loss: 0.1302
# Epoch 146/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0767 - val_loss: 0.1339
# Epoch 147/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0965 - val_loss: 0.1618
# Epoch 148/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0834 - val_loss: 0.1304
# Epoch 149/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0800 - val_loss: 0.1233
# Epoch 150/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0773 - val_loss: 0.1505
# Epoch 151/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0770 - val_loss: 0.1223
# Epoch 152/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0775 - val_loss: 0.1246
# Epoch 153/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0798 - val_loss: 0.1259
# Epoch 154/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0883 - val_loss: 0.1364
# Epoch 155/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0860 - val_loss: 0.1525
# Epoch 156/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0719 - val_loss: 0.1347
# Epoch 157/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0771 - val_loss: 0.1279
# Epoch 158/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0795 - val_loss: 0.1226
# Epoch 159/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0866 - val_loss: 0.1241
# Epoch 160/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0727 - val_loss: 0.1274
# Epoch 161/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0800 - val_loss: 0.1356
# Epoch 162/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0775 - val_loss: 0.1301
# Epoch 163/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0726 - val_loss: 0.1230
# Epoch 164/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0760 - val_loss: 0.1483
# Epoch 165/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0794 - val_loss: 0.1469
# Epoch 166/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0839 - val_loss: 0.1291
# Epoch 167/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0734 - val_loss: 0.1727
# Epoch 168/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0845 - val_loss: 0.1251
# Epoch 169/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0705 - val_loss: 0.1229
# Epoch 170/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0657 - val_loss: 0.1382
# Epoch 171/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0754 - val_loss: 0.1449
# Epoch 172/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0836 - val_loss: 0.1447
# Epoch 173/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1045 - val_loss: 0.1854
# Epoch 174/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0916 - val_loss: 0.1524
# Epoch 175/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0686 - val_loss: 0.1268
# Epoch 176/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0889 - val_loss: 0.2104
# Epoch 177/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.3155 - val_loss: 0.1842
# Epoch 178/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1580 - val_loss: 0.1452
# Epoch 179/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1236 - val_loss: 0.1107
# Epoch 180/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1072 - val_loss: 0.1104
# Epoch 181/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0976 - val_loss: 0.1252
# Epoch 182/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1018 - val_loss: 0.1398
# Epoch 183/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0959 - val_loss: 0.1394
# Epoch 184/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0873 - val_loss: 0.1359
# Epoch 185/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0806 - val_loss: 0.1332
# Epoch 186/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0862 - val_loss: 0.1586
# Epoch 187/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0747 - val_loss: 0.1687
# Epoch 188/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0742 - val_loss: 0.1279
# Epoch 189/300
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0733 - val_loss: 0.1179
# Epoch 190/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0814 - val_loss: 0.1282
# Epoch 191/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0730 - val_loss: 0.1244
# Epoch 192/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0761 - val_loss: 0.1147
# Epoch 193/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0708 - val_loss: 0.1303
# Epoch 194/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0755 - val_loss: 0.1400
# Epoch 195/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0791 - val_loss: 0.1271
# Epoch 196/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0745 - val_loss: 0.2859
# Epoch 197/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0843 - val_loss: 0.1222
# Epoch 198/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0787 - val_loss: 0.1259
# Epoch 199/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0653 - val_loss: 0.1223
# Epoch 200/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0692 - val_loss: 0.1225
# Epoch 201/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0814 - val_loss: 0.1336
# Epoch 202/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0726 - val_loss: 0.1212
# Epoch 203/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.0667 - val_loss: 0.1440
# Epoch 204/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0790 - val_loss: 0.1691
# Epoch 205/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0851 - val_loss: 0.1416
# Epoch 206/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1066 - val_loss: 0.2011
# Epoch 207/300
# 80/80 [==============================] - 1s 14ms/step - loss: 0.1134 - val_loss: 0.1342
# Epoch 208/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0826 - val_loss: 0.1197
# Epoch 209/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0874 - val_loss: 0.1562
# Epoch 210/300
# 78/80 [============================>.] - ETA: 0s - loss: 0.1598Restoring model weights from the end of the best epoch: 180.
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1630 - val_loss: 0.3630
# Epoch 210: early stopping
# 50/50 [==============================] - 0s 4ms/step
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#plot the loss
plt.plot(np.log(loss), label='Training Loss')
plt.plot(np.log(val_loss), label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('log loss')
plt.ylim(-4,2)
plt.legend()
plt.savefig('naive_loss.png')
plt.show()
