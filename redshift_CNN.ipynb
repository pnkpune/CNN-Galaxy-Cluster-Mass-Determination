# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from keras import backend
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Dense, Dropout, Concatenate, Input, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt




data_directory = 'training_data/'
# data_directory = '/Users/dawar/Desktop/AI Lab/x-ray-cluster-masses-23-l3/training_data/'
# data_directory = '/x-ray-cluster-masses-23-l3/code-examples/'
# data_directory = ''

image_file = 'eFEDS_01to18-3dImgs-7946clus-300pix-50pix-ext_det_thr.pickle'
catalog_file = 'eFEDS_mock_clusters_catalog_01to18-ext_det_thr.f'

def get_data(image_p, catalog_f):
    '''
    Given the image and catalogue path, this function returns the
    images and labels needed to start directly with model training.
    train_labels: Can be used to filter a particular mass range
    Returns:
    images: [index, energy-band-image]
    labels_z: [log10(mass), redshift, index]
    '''
    is_efedssim=True
    is_efedsobs=False
    images = pd.read_pickle(image_p)
    key_mass = 'm500_wl_final' if is_efedsobs else 'M500c' if is_efedssim else 'HALO_M500c'
    key_redshift = 'z_final' if is_efedsobs else 'z' if is_efedssim else 'redshift_R'
    catalog_df = pd.read_feather(catalog_f)
    labels = np.log10(catalog_df[key_mass])
    redshifts = catalog_df[key_redshift].values
    indices = catalog_df.index.values
    labels_z = np.transpose([labels, redshifts, indices])
    return images, labels_z

images, labels_z = get_data(image_p=data_directory+image_file, catalog_f=data_directory+catalog_file)
print(len(images))
print(len(labels_z))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# 2
# 7946
# Num GPUs Available:  1

# %%
# Get mass and redshift values from the labels_z array
masses = labels_z[:,0]
redshifts = labels_z[:,1]

# %%
# Split the data into training, validation, and test sets
# The random state ensures that the split is reproducible
X_train, X_test, y_train, y_test = train_test_split(images['gsm_3dImgs'], np.stack((masses, redshifts), axis=1), test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)


# Print the shapes of the resulting sets
print(f"Train set: {X_train.shape}, {y_train.shape}")
print(f"Validation set: {X_val.shape}, {y_val.shape}")
print(f"Test set: {X_test.shape}, {y_test.shape}")
# Out:
# Train set: (5084, 50, 50, 10), (5084, 2)
# Validation set: (1272, 50, 50, 10), (1272, 2)
# Test set: (1590, 50, 50, 10), (1590, 2)

# %%
import numpy as np
import tensorflow as tf

def log_gauss_error(y_true, y_pred):

    ''' Cost function as the negative log-likelihood '''
    
    y_pred_0 = y_pred[:, 0]
    y_pred_1 = y_pred[:, 1]

    y_pred_0 = tf.convert_to_tensor(y_pred_0)
    y_pred_1 = tf.convert_to_tensor(y_pred_1)
    y_true = tf.cast(y_true, y_pred.dtype)

    error = 0.5 * tf.math.squared_difference(y_pred_0, y_true)
    error += 0.5 * tf.math.log(2 * tf.constant(np.pi) * y_pred_1 ** 2)
    return tf.reduce_mean(error, axis=-1)

# %%
# Define the model

early_stopping = EarlyStopping(monitor='val_loss', patience=30, verbose=0, mode='min', restore_best_weights=True)
model = Sequential()
## Data augmentation
data_augmentation = Sequential([
    RandomFlip("horizontal"),
    RandomRotation(0.1),
])
model.add(Conv2D(10, (3, 3), activation='relu', input_shape=(50, 50, 10)))  # Updated input shape
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(20, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(30, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))


# Concatenate the redshift information
redshift_input = Input(shape=(1,))
concatenated = Concatenate()([model.output, redshift_input])

# Add a final output layer for regression
output = Dense(1, activation='linear')(concatenated)

# Create the model
model = Model(inputs=[model.input, redshift_input], outputs=output)

# Define the optimizer
optimizer = Adam()

# Compile the model
model.compile(optimizer=optimizer, loss='mean_squared_error')


# Print the model summary
model.summary()
# Out:
# Metal device set to: Apple M1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  conv2d_input (InputLayer)      [(None, 50, 50, 10)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 48, 48, 10)   910         ['conv2d_input[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 24, 24, 10)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 22, 22, 20)   1820        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 11, 11, 20)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 9, 9, 30)     5430        ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 30)    0           ['conv2d_2[0][0]']
#
#  flatten (Flatten)              (None, 480)          0           ['max_pooling2d_2[0][0]']
#
#  dense (Dense)                  (None, 64)           30784       ['flatten[0][0]']
#
#  input_1 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate (Concatenate)      (None, 65)           0           ['dense[0][0]',
#                                                                   'input_1[0][0]']
#
#  dense_1 (Dense)                (None, 1)            66          ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 39,010
# Trainable params: 39,010
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Train the model with augmented data
history = model.fit([X_train, y_train[:, 1]], y_train[:, 0], 
                    validation_data=([X_val, y_val[:, 1]], y_val[:, 0]), 
                    epochs=300, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/300
# 2023-05-26 20:47:47.436490: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 80/80 [==============================] - 7s 50ms/step - loss: 121.6693 - val_loss: 15.7400
# Epoch 2/300
# 80/80 [==============================] - 1s 17ms/step - loss: 10.0090 - val_loss: 1.1151
# Epoch 3/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.9191 - val_loss: 0.4506
# Epoch 4/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.4981 - val_loss: 0.4034
# Epoch 5/300
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3304 - val_loss: 0.3062
# Epoch 6/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2890 - val_loss: 0.3210
# Epoch 7/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2684 - val_loss: 0.2858
# Epoch 8/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2536 - val_loss: 0.2752
# Epoch 9/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2396 - val_loss: 0.2569
# Epoch 10/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2556 - val_loss: 0.2384
# Epoch 11/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.2832 - val_loss: 0.3109
# Epoch 12/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.3475 - val_loss: 0.2324
# Epoch 13/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.3844 - val_loss: 0.2899
# Epoch 14/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.5136 - val_loss: 0.2721
# Epoch 15/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.3620 - val_loss: 0.2321
# Epoch 16/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.3420 - val_loss: 0.2335
# Epoch 17/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.2756 - val_loss: 0.1957
# Epoch 18/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.2481 - val_loss: 0.2069
# Epoch 19/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1993 - val_loss: 0.2188
# Epoch 20/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1977 - val_loss: 0.1811
# Epoch 21/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1676 - val_loss: 0.1931
# Epoch 22/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1788 - val_loss: 0.2909
# Epoch 23/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1739 - val_loss: 0.2188
# Epoch 24/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1719 - val_loss: 0.1632
# Epoch 25/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1916 - val_loss: 0.1850
# Epoch 26/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1892 - val_loss: 0.1544
# Epoch 27/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2351 - val_loss: 0.1625
# Epoch 28/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2519 - val_loss: 0.1592
# Epoch 29/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2027 - val_loss: 0.1905
# Epoch 30/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2173 - val_loss: 0.2357
# Epoch 31/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1838 - val_loss: 0.2004
# Epoch 32/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1663 - val_loss: 0.1606
# Epoch 33/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1805 - val_loss: 0.1447
# Epoch 34/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.1550 - val_loss: 0.1837
# Epoch 35/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1564 - val_loss: 0.1768
# Epoch 36/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1516 - val_loss: 0.1317
# Epoch 37/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1455 - val_loss: 0.1318
# Epoch 38/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1313 - val_loss: 0.1623
# Epoch 39/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1735 - val_loss: 0.1322
# Epoch 40/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.3596 - val_loss: 0.1585
# Epoch 41/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1454 - val_loss: 0.1638
# Epoch 42/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.1428 - val_loss: 0.1269
# Epoch 43/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.2901 - val_loss: 0.1151
# Epoch 44/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.4604 - val_loss: 0.3989
# Epoch 45/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.2305 - val_loss: 0.1819
# Epoch 46/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1804 - val_loss: 0.1057
# Epoch 47/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.2455 - val_loss: 0.1011
# Epoch 48/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1116 - val_loss: 0.0964
# Epoch 49/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0923 - val_loss: 0.0962
# Epoch 50/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0827 - val_loss: 0.1118
# Epoch 51/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0807 - val_loss: 0.1134
# Epoch 52/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0797 - val_loss: 0.0935
# Epoch 53/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0782 - val_loss: 0.1000
# Epoch 54/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0866 - val_loss: 0.1648
# Epoch 55/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0943 - val_loss: 0.0912
# Epoch 56/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0801 - val_loss: 0.0875
# Epoch 57/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0762 - val_loss: 0.0886
# Epoch 58/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0832 - val_loss: 0.0834
# Epoch 59/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0781 - val_loss: 0.0911
# Epoch 60/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0836 - val_loss: 0.0856
# Epoch 61/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0924 - val_loss: 0.1705
# Epoch 62/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.1004 - val_loss: 0.0955
# Epoch 63/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0754 - val_loss: 0.0833
# Epoch 64/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0717 - val_loss: 0.1589
# Epoch 65/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0710 - val_loss: 0.0839
# Epoch 66/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0702 - val_loss: 0.0761
# Epoch 67/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0653 - val_loss: 0.1219
# Epoch 68/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0649 - val_loss: 0.1137
# Epoch 69/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0797 - val_loss: 0.0800
# Epoch 70/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0635 - val_loss: 0.1026
# Epoch 71/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0666 - val_loss: 0.0955
# Epoch 72/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0708 - val_loss: 0.0749
# Epoch 73/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0683 - val_loss: 0.0756
# Epoch 74/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0703 - val_loss: 0.0823
# Epoch 75/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0656 - val_loss: 0.1089
# Epoch 76/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0708 - val_loss: 0.0745
# Epoch 77/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0760 - val_loss: 0.0736
# Epoch 78/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0838 - val_loss: 0.0997
# Epoch 79/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0816 - val_loss: 0.0735
# Epoch 80/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0855 - val_loss: 0.0778
# Epoch 81/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0843 - val_loss: 0.0729
# Epoch 82/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0719 - val_loss: 0.0836
# Epoch 83/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0716 - val_loss: 0.0730
# Epoch 84/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0643 - val_loss: 0.0865
# Epoch 85/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0616 - val_loss: 0.1122
# Epoch 86/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0689 - val_loss: 0.0816
# Epoch 87/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0619 - val_loss: 0.0724
# Epoch 88/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0628 - val_loss: 0.0702
# Epoch 89/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0754 - val_loss: 0.1209
# Epoch 90/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0798 - val_loss: 0.0791
# Epoch 91/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0636 - val_loss: 0.1144
# Epoch 92/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0611 - val_loss: 0.1511
# Epoch 93/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0741 - val_loss: 0.0693
# Epoch 94/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0662 - val_loss: 0.0690
# Epoch 95/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0548 - val_loss: 0.0671
# Epoch 96/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0585 - val_loss: 0.0862
# Epoch 97/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0705 - val_loss: 0.0737
# Epoch 98/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0652 - val_loss: 0.0807
# Epoch 99/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0595 - val_loss: 0.0831
# Epoch 100/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0665 - val_loss: 0.0680
# Epoch 101/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0629 - val_loss: 0.0739
# Epoch 102/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0727 - val_loss: 0.0701
# Epoch 103/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0571 - val_loss: 0.0719
# Epoch 104/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0615 - val_loss: 0.0895
# Epoch 105/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0546 - val_loss: 0.0735
# Epoch 106/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0560 - val_loss: 0.0717
# Epoch 107/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0578 - val_loss: 0.0723
# Epoch 108/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0636 - val_loss: 0.0832
# Epoch 109/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0651 - val_loss: 0.1087
# Epoch 110/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0633 - val_loss: 0.0783
# Epoch 111/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0573 - val_loss: 0.0695
# Epoch 112/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0580 - val_loss: 0.0686
# Epoch 113/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0611 - val_loss: 0.0858
# Epoch 114/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0610 - val_loss: 0.0693
# Epoch 115/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0577 - val_loss: 0.0683
# Epoch 116/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0548 - val_loss: 0.0749
# Epoch 117/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0523 - val_loss: 0.0714
# Epoch 118/300
# 80/80 [==============================] - 1s 15ms/step - loss: 0.0765 - val_loss: 0.0836
# Epoch 119/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0687 - val_loss: 0.0964
# Epoch 120/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0754 - val_loss: 0.0807
# Epoch 121/300
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0762 - val_loss: 0.0706
# Epoch 122/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0719 - val_loss: 0.0676
# Epoch 123/300
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0768 - val_loss: 0.0841
# Epoch 124/300
# 80/80 [==============================] - 1s 16ms/step - loss: 0.0750 - val_loss: 0.0726
# Epoch 125/300
# 80/80 [==============================] - 1s 17ms/step - loss: 0.0629 - val_loss: 0.0822

# %%
model.save('models/redshift_best_CNN.h5')

# %%
# Plot training and validation loss
val_loss = history.history['val_loss']
train_loss = history.history['loss']


plt.plot(np.log(train_loss), label='Training Loss')
plt.plot(np.log(val_loss), label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Log of validation loss')
plt.ylim(-3.5,0)
plt.legend()
plt.savefig('output_data/redshift_CNN_loss.png', dpi=300)
plt.show()

# %%
# Get predictions on test set and calculate scatter
y_pred = model.predict([X_test, y_test[:, 1]])
plt.scatter(y_test[:, 0], y_pred, alpha=0.1)
plt.plot([13, 15], [13, 15], 'r--')
plt.xlim(13, 15)
plt.ylim(13, 15)
plt.xlabel('True Mass')
plt.ylabel('Predicted Mass')
plt.savefig('output_data/predictions_redshift_CNN.png', dpi=300)
plt.show()
# Out:
# 50/50 [==============================] - 1s 12ms/step
